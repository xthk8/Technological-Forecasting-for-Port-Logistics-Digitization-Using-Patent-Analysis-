# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re
import lda
# from konlpy.tag import Okt 이거 Komoran보다 별로 복합명사 처리하기 Komoran이 유리
from konlpy.tag import Komoran
from ugtm import eGTM
import altair as alt

# %%
# Okt 객체를 생성합니다. (형태소 분석기)
# okt = Okt()

# Komoran 객체를 생성합니다. (형태소 분석기)
komoran = Komoran()

# %%
# # 복합명사 목록
compound_nouns = [
    "인공지능", "데이터베이스", "블록체인", "웨어러블", "물류센터", "무선통신", "자동화", "메타데이터", "메타버스", "작업시간", "예정시간",
    "기계학습", "강화학습", "빅데이터", "위치정보", "물류창고", "항만물류정보시스템", "항만물류", "물류관리시스템", "무인이동체", "항적정보",
    "자율주행",  "웨어러블", "정보보안", "자율운항선박", "머신러닝", "딥러닝", "디바이스", "제어창치", "야드트랙터", "로드트랙터", "항해정보",
    "자동화시스템",  "선박자동식별시스템", "무인이송차량", "자율운항", "원격제어", "제어정보", "감지센서", "온도센서", "자동화창고", "수신장치",
    "선박위치정보", "식별정보", "경로정보", "경로계획", "화물운송", "화물운송정보", "화물운송시스템", "야드크레인", "안벽크레인", "선박정보", 
    "위성정보", "위성통신", "식별장치", "운항경로", "물류정보", "화물보관", "화물차량", "경로탐색", "프레임워크", "해상운임지수", "네트워크",
    "파라미터", "콜드체인", "트레이", "다중선형회귀", "가이드레일", "연료저장탱크"
]
# 사용자 사전을 파일에 추가
with open('user_dict.txt', 'w') as f:
    for compound in compound_nouns:
        f.write(f'{compound}\tNNP\n')  # 각 단어와 태그 사이에 탭 문자를 사용
# Komoran 객체에 사용자 사전 적용
komoran = Komoran(userdic='user_dict.txt')

# %%
def preprocess(text):
    # 영어 단어를 따로 추출하여 보존
    english_words = re.findall(r'[a-zA-Z]+', text)
    
    # 특수 문자 제거
    text = re.sub(r'[^가-힣\s]', '', text)  # 한글과 공백을 제외하고 모두 제거
    text = re.sub(r'\s+', ' ', text)  # 중복 공백 제거
    text = text.strip()
    
    # 형태소 분석 및 명사 추출
    tokens = komoran.nouns(text)
    
    # 불용어 제거
    tokens = [word for word in tokens if word not in stop_words]
    
        # 영어 단어에서 불용어 제거
    english_words = [word for word in english_words if word.lower() not in stop_words_en]
    
    
    # 영어 단어와 한국어 명사를 결합
    tokens.extend(english_words)
    
    return ' '.join(tokens)

# %%
# 결과 출력 함수
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.topic_word_):
        print(f"Topic #{topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()
# def print_top_words(model, feature_names, n_top_words):
#     for topic_idx, topic in enumerate(model.topic_word_):
#         print(", ".join([f'"{feature_names[i]}"' for i in topic.argsort()[:-n_top_words - 1:-1]]))
#     print()

# # 상위 단어와 확률을 출력하는 함수
# def print_top_words(model, feature_names, n_top_words):
#     topic_word_distributions = model.topic_word_
#     for topic_idx, topic in enumerate(topic_word_distributions):
#         print(f"Topic #{topic_idx}:")
#         top_words_idx = topic.argsort()[-n_top_words:][::-1]  # 상위 n개 단어
#         for idx in top_words_idx:
#             print(f"{feature_names[idx]} ({topic[idx]:.4f})", end=" ")
#         print("\n")

# %%
def perform_lda_and_save(n_topics, output_file):
    # 토픽 수와 랜덤 시드 설정
    n_models = 50
    n_iter = 5000
    random_seeds = np.random.randint(0, 10000, n_models)

    # 각 토픽 수에 대해 50개의 모델을 생성하고 결과를 저장합니다.
    with open(output_file, 'w') as f:
        for seed in random_seeds:
            model = lda.LDA(n_topics=n_topics, n_iter=n_iter, random_state=seed)
            model.fit(count_matrix)
            
            f.write(f'Random Seed: {seed}\n')
            for i, topic_dist in enumerate(model.topic_word_):
                topic_words = np.array(count_vectorizer.get_feature_names_out())[np.argsort(topic_dist)][:-11:-1]
                f.write(f'Topic {i}: {" ".join(topic_words)}\n')
            f.write('\n')

# %%
# CSV 파일을 읽어옵니다.
file_path = '/Users/woosu/Desktop/KLIP/patent_data_v.3.4.csv'  # 파일 경로를 지정하세요.
df = pd.read_csv(file_path)
# K 열의 'sum' 열 데이터를 추출합니다.
documents = df['claim'].astype(str).tolist()

# %%
stop_words = [
    "물품", "장치", "결정", "방법", "단계", "사용자", "복수", "프로세서", "지지", "기상", "상황", "변화", "모드", "패킷", "서브",
    "데이터", "관리", "저장", "정보", "보안", "생성", "전자", "컴퓨터", "코드", "물류", "업체", "기자재", "상면", "기간", "표준", "발전",
    "운임", "해상", "분석", "시스템", "화물", "운송", "요청", "서버", "경우", "송사", "전압", "중심", "서비스", "모델링",
    "고상", "전송", "입력", "통신", "네트워크", "삭제", "노드", "수신", "신호", "육상", "단위", "누적", "운영", "높이", "처리",
    "메시지", "차량", "이동", "모듈", "영상", "제어", "시스템", "인식", "장비", "적재", "처리", "물질", "진단", "기기", "사항", 
    "반출", "대상", "시간", "지연", "이용", "상태", "결합", "구비", "연결", "평가", "표시", "이용한", "교차", "냉동", "신고",
    "특징", "방향", "이송", "설치", "형성", "이상", "디바이스", "물체", "할당", "실행", "확인", "단말", "중앙", "피스톤", "단일", "행동", "관리",
    "기반", "동작", "설정", "수행", "제공", "기능", "출입", "선택", "수직", "구동", "관리자", "파지", "목록", "접수", "승인", "통지",
    "프레임", "고정", "회전", "유닛", "가이드", "상부", "부재", "식별자", "이벤트", "아이템", "주문", "대응", "포인트", "표현", "오류",
    "외부", "내부", "구조", "연산", "구조물", "라인", "기초", "패키지", "과정", "하부", "본체", "수단", "구성", "몸체", "회수", 
    "해당", "결과", "프로세스", "획득", "영역", "블록", "픽셀", "사이즈", "전극", "등록", "전달", "메인", "패널", "관제소", 
    "자원", "그룹", "가시", "수식", "자루", "측위", "특성", "고객", "산출", "단말기", "의뢰", "케이슨", "파일", "조건", "취합",
    "출력", "측면", "구동", "상품", "목표", "로딩", "임무", "스테이션", "번호", "분배", "구현", "객체", "체부", "박용", "상승", "동시", "전단",
    "촬영", "항만", "운행", "본선", "선반", "앵커", "여부", "입찰", "특정", "판단", "수입", "작업", "스토커", "물리", "기구", "신청",
    "플레이트", "연장", "실제", "수집", "운용", "박스", "대역", "자산", "타겟", "형상", "연관", "워크", "완료", "각각", "비교", "상대",
    "하강","내측", "베어링", "지면", "후크", "일체", "소형", "정부", "이동식", "모선","지도", "근거", "야적장",  "분포", "조명", "용도", "반응", "레이저", "메타데이터",
    "등급", "해운", "기계", "종류", "제한", "수요", "인자", "영향", "적용","트래픽", "컴퓨팅", "예방", "회피", "속력", "조종", "리스크", "속도", "평균",
    "보상", "가중치", "기사", "과거", "전용", "유도", "릴레이", "헤드", "횡단", "이어", "분리", "평행", "포트", "부하", "변수", "순위", "기록", "출발", "국내", "연계",
    "링크", "부피", "정렬", "효율", "에너지", "해양", "취약점","계약", "추진부", "밸브", "인력", "방위", "수준", "조작", "선수", "선장","비디오",
    "일부", "신한", "개수", "팔레트", "하기", "손상", "변동", "서비스", "주행", "해저", "고장", "압력", "배포", "기관", "유동", "브레이", "선로", "로프", "볼트",
    "사용자", "시스템", "센터", "인터페이스","선형","신축", "상위", "슬롯", "리퍼", "배열", "하나에", "멀티","중간", "인수", "탄성", "시공", "리드", "외면", "확장",
    "제출", "레일", "롤러", "분류", "물류창고", "감소", "제거", "초기", "성분", "검출", "분류", "전체", "정상", "기재", "거부",
]

# %%
stop_words_en = ["nan", "data", "dt", "nft", "os", "rsu", "db", "vhf", "mhz", "id", "lte", "gpu"]

# %%
preprocessed_documents = [preprocess(doc) for doc in documents]

# %%
# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, min_df=2,)
tfidf = tfidf_vectorizer.fit_transform(preprocessed_documents)

# TF-IDF 가중치를 기반으로 중요한 단어 선택
tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
tfidf_scores = np.array(tfidf.sum(axis=0)).flatten()
sorted_indices = np.argsort(tfidf_scores)[::-1]
# n_top_words = 2275  # 선택할 단어의 수
# top_words = sorted_indices[:n_top_words]
# selected_features = [tfidf_feature_names[i] for i in top_words]
# 임계값 설정
threshold = 0.9
selected_indices = np.where(tfidf_scores > threshold)[0]
selected_features = [tfidf_feature_names[i] for i in selected_indices]

# 선택된 단어로 새로운 Count 행렬 생성
count_vectorizer = CountVectorizer(vocabulary=selected_features)
count_matrix = count_vectorizer.fit_transform(preprocessed_documents)

# 모든 값이 0인 행 제거
nonzero_row_indices = np.where(count_matrix.sum(axis=1) != 0)[0]
count_matrix = count_matrix[nonzero_row_indices]

# 해당 문서들도 제거
preprocessed_documents = [preprocessed_documents[i] for i in nonzero_row_indices]

# %%
# # TF-IDF 가중치 순으로 단어와 가중치 출력
# print("TF-IDF 가중치 순으로 단어와 가중치 출력:")
# for i in sorted_indices:
#     print(f"{tfidf_feature_names[i]}: {tfidf_scores[i]:.4f}")

# %%
# LDA 수행 (lda 라이브러리 사용)
n_topics = 7  # 토픽의 수 (조정 가능)
model = lda.LDA(n_topics=n_topics, n_iter=5000, random_state=4170)
model.fit(count_matrix)

# for i in range(10,20):
#     n_topics = 7  # 토픽의 수 (조정 가능)
#     model = lda.LDA(n_topics=n_topics, n_iter=5000, random_state=i)
#     model.fit(count_matrix)
#     print_top_words(model, count_vectorizer.get_feature_names_out(), 10)
# Out:
# INFO:lda:n_documents: 401
# INFO:lda:<690> log likelihood: -146639
# INFO:lda:<700> log likelihood: -146759
# INFO:lda:<710> log likelihood: -146792
# INFO:lda:<720> log likelihood: -146582
# INFO:lda:<730> log likelihood: -146726
# INFO:lda:<740> log likelihood: -146706
# INFO:lda:<750> log likelihood: -146579
# INFO:lda:<760> log likelihood: -146659
# INFO:lda:<770> log likelihood: -146424
# INFO:lda:<780> log likelihood: -146529
# INFO:lda:<790> log likelihood: -146524
# INFO:lda:<800> log likelihood: -146763
# INFO:lda:<810> log likelihood: -146562
# INFO:lda:<820> log likelihood: -146742
# INFO:lda:<830> log likelihood: -146692
# INFO:lda:<840> log likelihood: -146527
# INFO:lda:<850> log likelihood: -146541
# INFO:lda:<860> log likelihood: -146358
# INFO:lda:<870> log likelihood: -146526
# INFO:lda:<880> log likelihood: -146519
# INFO:lda:<890> log likelihood: -146492
# INFO:lda:<900> log likelihood: -146215
# INFO:lda:<910> log likelihood: -146484
# INFO:lda:<920> log likelihood: -146427
# INFO:lda:<930> log likelihood: -146279
# INFO:lda:<940> log likelihood: -146617
# INFO:lda:<950> log likelihood: -146425
# INFO:lda:<960> log likelihood: -146363
# INFO:lda:<970> log likelihood: -146397
# INFO:lda:<980> log likelihood: -146468
# INFO:lda:<990> log likelihood: -146656
# INFO:lda:<1000> log likelihood: -146511
# INFO:lda:<1010> log likelihood: -146241
# INFO:lda:<1020> log likelihood: -146322
# INFO:lda:<1030> log likelihood: -146247
# INFO:lda:<1040> log likelihood: -146388
# INFO:lda:<1050> log likelihood: -146303
# INFO:lda:<1060> log likelihood: -146160
# INFO:lda:<1070> log likelihood: -146146
# INFO:lda:<1080> log likelihood: -146326
# INFO:lda:<1090> log likelihood: -146057
# INFO:lda:<1100> log likelihood: -146148
# INFO:lda:<1110> log likelihood: -146237
# INFO:lda:<1120> log likelihood: -146139
# INFO:lda:<1130> log likelihood: -146217
# INFO:lda:<1140> log likelihood: -146150
# INFO:lda:<1150> log likelihood: -146009
# INFO:lda:<1160> log likelihood: -146067
# INFO:lda:<1170> log likelihood: -145952
# INFO:lda:<1180> log likelihood: -145961
# INFO:lda:<1190> log likelihood: -145952
# INFO:lda:<1200> log likelihood: -146067
# INFO:lda:<1210> log likelihood: -146074
# INFO:lda:<1220> log likelihood: -145975
# INFO:lda:<1230> log likelihood: -146026
# INFO:lda:<1240> log likelihood: -146014
# INFO:lda:<1250> log likelihood: -146082
# INFO:lda:<1260> log likelihood: -145880
# INFO:lda:<1270> log likelihood: -145950
# INFO:lda:<1280> log likelihood: -146088
# INFO:lda:<1290> log likelihood: -146096
# INFO:lda:<1300> log likelihood: -146069
# INFO:lda:<1310> log likelihood: -146018
# INFO:lda:<1320> log likelihood: -146016
# INFO:lda:<1330> log likelihood: -146013
# INFO:lda:<1340> log likelihood: -146067
# INFO:lda:<1350> log likelihood: -146274
# INFO:lda:<1360> log likelihood: -146112
# INFO:lda:<1370> log likelihood: -146012
# INFO:lda:<1380> log likelihood: -146081
# INFO:lda:<1390> log likelihood: -146066
# INFO:lda:<1400> log likelihood: -146081
# INFO:lda:<1410> log likelihood: -145833
# INFO:lda:<1420> log likelihood: -146035
# INFO:lda:<1430> log likelihood: -146119
# INFO:lda:<1440> log likelihood: -145932
# INFO:lda:<1450> log likelihood: -145945
# INFO:lda:<1460> log likelihood: -145951
# INFO:lda:<1470> log likelihood: -145929
# INFO:lda:<1480> log likelihood: -146029
# INFO:lda:<1490> log likelihood: -145927
# INFO:lda:<1500> log likelihood: -145928
# INFO:lda:<1510> log likelihood: -145993
# INFO:lda:<1520> log likelihood: -145994
# INFO:lda:<1530> log likelihood: -145785
# INFO:lda:<1540> log likelihood: -145883
# INFO:lda:<1550> log likelihood: -146044
# INFO:lda:<1560> log likelihood: -145864
# INFO:lda:<1570> log likelihood: -146035
# INFO:lda:<1580> log likelihood: -146031
# INFO:lda:<1590> log likelihood: -145947
# INFO:lda:<1600> log likelihood: -146165
# INFO:lda:<1610> log likelihood: -145813
# INFO:lda:<1620> log likelihood: -146185
# INFO:lda:<1630> log likelihood: -146027
# INFO:lda:<1640> log likelihood: -146067
# INFO:lda:<1650> log likelihood: -145950
# INFO:lda:<1660> log likelihood: -146126
# INFO:lda:<1670> log likelihood: -146004
# INFO:lda:<1680> log likelihood: -146146
# INFO:lda:<1690> log likelihood: -146108
# INFO:lda:<1700> log likelihood: -145930
# INFO:lda:<1710> log likelihood: -146021
# INFO:lda:<1720> log likelihood: -146078
# INFO:lda:<1730> log likelihood: -145668
# INFO:lda:<1740> log likelihood: -146062
# INFO:lda:<1750> log likelihood: -145824
# INFO:lda:<1760> log likelihood: -145934
# INFO:lda:<1770> log likelihood: -145932
# INFO:lda:<1780> log likelihood: -145891
# INFO:lda:<1790> log likelihood: -146035
# INFO:lda:<1800> log likelihood: -146032
# INFO:lda:<1810> log likelihood: -146173
# INFO:lda:<1820> log likelihood: -145966
# INFO:lda:<1830> log likelihood: -146015
# INFO:lda:<1840> log likelihood: -145787
# INFO:lda:<1850> log likelihood: -145908
# INFO:lda:<1860> log likelihood: -145951
# INFO:lda:<1870> log likelihood: -145851
# INFO:lda:<1880> log likelihood: -145833
# INFO:lda:<1890> log likelihood: -145884
# INFO:lda:<1900> log likelihood: -145843
# INFO:lda:<1910> log likelihood: -146001
# INFO:lda:<1920> log likelihood: -145910
# INFO:lda:<1930> log likelihood: -145872
# INFO:lda:<1940> log likelihood: -145838
# INFO:lda:<1950> log likelihood: -145893
# INFO:lda:<1960> log likelihood: -146046
# INFO:lda:<1970> log likelihood: -145766
# INFO:lda:<1980> log likelihood: -145821
# INFO:lda:<1990> log likelihood: -145863
# INFO:lda:<2000> log likelihood: -145897
# INFO:lda:<2010> log likelihood: -145875
# INFO:lda:<2020> log likelihood: -145863
# INFO:lda:<2030> log likelihood: -145924
# INFO:lda:<2040> log likelihood: -145963
# INFO:lda:<2050> log likelihood: -145799
# INFO:lda:<2060> log likelihood: -145806
# INFO:lda:<2070> log likelihood: -145956
# INFO:lda:<2080> log likelihood: -145973
# INFO:lda:<2090> log likelihood: -145721
# INFO:lda:<4880> log likelihood: -144109
# INFO:lda:<4890> log likelihood: -144288
# INFO:lda:<4900> log likelihood: -144370
# INFO:lda:<4910> log likelihood: -144128
# INFO:lda:<4920> log likelihood: -144274
# INFO:lda:<4930> log likelihood: -144248
# INFO:lda:<4940> log likelihood: -144243
# INFO:lda:<4950> log likelihood: -144181
# INFO:lda:<4960> log likelihood: -144366
# INFO:lda:<4970> log likelihood: -144368
# INFO:lda:<4980> log likelihood: -144344
# INFO:lda:<4990> log likelihood: -144434
# INFO:lda:<4999> log likelihood: -144217

# %%
print_top_words(model, count_vectorizer.get_feature_names_out(), 10)
# Out:
# Topic #0:
# 컨테이너 위치 이미지 운반 터미널 크레인 스캐닝 야드 트레일러 핸드오버
# Topic #1:
# 크레인 계획 자동화 터미널 정보 도착 서비스 물류 시뮬레이션 경유
# Topic #2:
# 태그 온도 센서 스마트 창고 디지털 위치 iot qr 실시간
# Topic #3:
# 예측 모델 블록체인 스케줄 선적 로드트랙터 항만물류 학습 알고리즘 비용
# Topic #4:
# 위치 센서 로봇 거리 카메라 광학 운반 좌표 추적 창고
# Topic #5:
# 원격제어 위치 충돌 위험 ais 자율운항선박 감시 추정 클라우드 송수신
# Topic #6:
# 경로 야드트랙터 통신 목적지 무선 연료 위치 장애물 화물차량 자율주행

# %%
# 각각의 토픽 수에 대해 독립적으로 실행
perform_lda_and_save(7, 'lda_topics_7.txt')
# Out:
# INFO:lda:n_documents: 401
# INFO:lda:vocab_size: 412
# INFO:lda:n_words: 31088
# INFO:lda:n_topics: 7
# INFO:lda:n_iter: 5000
# INFO:lda:<0> log likelihood: -243146
# INFO:lda:<10> log likelihood: -155132
# INFO:lda:<20> log likelihood: -151298
# INFO:lda:<30> log likelihood: -149722
# INFO:lda:<40> log likelihood: -149113
# INFO:lda:<50> log likelihood: -148521
# INFO:lda:<60> log likelihood: -148141
# INFO:lda:<70> log likelihood: -147236
# INFO:lda:<80> log likelihood: -146583
# INFO:lda:<90> log likelihood: -146284
# INFO:lda:<100> log likelihood: -146041
# INFO:lda:<110> log likelihood: -145788
# INFO:lda:<120> log likelihood: -145569
# INFO:lda:<130> log likelihood: -145318
# INFO:lda:<140> log likelihood: -145262
# INFO:lda:<150> log likelihood: -145357
# INFO:lda:<160> log likelihood: -145048
# INFO:lda:<170> log likelihood: -144992
# INFO:lda:<180> log likelihood: -144554
# INFO:lda:<190> log likelihood: -144597
# INFO:lda:<200> log likelihood: -144760
# INFO:lda:<210> log likelihood: -144822
# INFO:lda:<220> log likelihood: -144545
# INFO:lda:<230> log likelihood: -144551
# INFO:lda:<240> log likelihood: -144474
# INFO:lda:<250> log likelihood: -144476
# INFO:lda:<260> log likelihood: -144470
# INFO:lda:<270> log likelihood: -144418
# INFO:lda:<280> log likelihood: -144432
# INFO:lda:<290> log likelihood: -144477
# INFO:lda:<300> log likelihood: -144342
# INFO:lda:<310> log likelihood: -144314
# INFO:lda:<320> log likelihood: -144333
# INFO:lda:<330> log likelihood: -144285
# INFO:lda:<340> log likelihood: -144162
# INFO:lda:<350> log likelihood: -144220
# INFO:lda:<360> log likelihood: -144351
# INFO:lda:<370> log likelihood: -144269
# INFO:lda:<380> log likelihood: -144387
# INFO:lda:<390> log likelihood: -144215
# INFO:lda:<400> log likelihood: -144268
# INFO:lda:<410> log likelihood: -144157
# INFO:lda:<420> log likelihood: -144025
# INFO:lda:<430> log likelihood: -144231
# INFO:lda:<440> log likelihood: -144217
# INFO:lda:<450> log likelihood: -144015
# INFO:lda:<460> log likelihood: -143965
# INFO:lda:<470> log likelihood: -144110
# INFO:lda:<480> log likelihood: -143866
# INFO:lda:<490> log likelihood: -143883
# INFO:lda:<500> log likelihood: -144094
# INFO:lda:<510> log likelihood: -143976
# INFO:lda:<520> log likelihood: -144009
# INFO:lda:<530> log likelihood: -143949
# INFO:lda:<540> log likelihood: -143946
# INFO:lda:<550> log likelihood: -143899
# INFO:lda:<560> log likelihood: -144020
# INFO:lda:<570> log likelihood: -143929
# INFO:lda:<580> log likelihood: -144066
# INFO:lda:<590> log likelihood: -143896
# INFO:lda:<600> log likelihood: -143980
# INFO:lda:<610> log likelihood: -143959
# INFO:lda:<620> log likelihood: -143937
# INFO:lda:<630> log likelihood: -144052
# INFO:lda:<640> log likelihood: -143990
# INFO:lda:<650> log likelihood: -143759
# INFO:lda:<660> log likelihood: -143942
# INFO:lda:<670> log likelihood: -144103
# INFO:lda:<680> log likelihood: -143986
# INFO:lda:<690> log likelihood: -143978
# INFO:lda:<700> log likelihood: -143794
# INFO:lda:<710> log likelihood: -143971
# INFO:lda:<720> log likelihood: -143979
# INFO:lda:<730> log likelihood: -143780
# INFO:lda:<740> log likelihood: -143843
# INFO:lda:<750> log likelihood: -143953
# INFO:lda:<760> log likelihood: -143803
# INFO:lda:<770> log likelihood: -143966
# INFO:lda:<780> log likelihood: -143872
# INFO:lda:<790> log likelihood: -143850
# INFO:lda:<800> log likelihood: -143957
# INFO:lda:<810> log likelihood: -143941
# INFO:lda:<820> log likelihood: -143849
# INFO:lda:<830> log likelihood: -143800
# INFO:lda:<840> log likelihood: -143740
# INFO:lda:<850> log likelihood: -143859
# INFO:lda:<860> log likelihood: -143806
# INFO:lda:<870> log likelihood: -143804
# INFO:lda:<880> log likelihood: -143738
# INFO:lda:<890> log likelihood: -143932
# INFO:lda:<900> log likelihood: -143789
# INFO:lda:<910> log likelihood: -143891
# INFO:lda:<920> log likelihood: -143745
# INFO:lda:<930> log likelihood: -143748
# INFO:lda:<940> log likelihood: -143737
# INFO:lda:<950> log likelihood: -143808
# INFO:lda:<960> log likelihood: -143653
# INFO:lda:<970> log likelihood: -143588
# INFO:lda:<980> log likelihood: -143632
# INFO:lda:<990> log likelihood: -143575
# INFO:lda:<1000> log likelihood: -143676
# INFO:lda:<1010> log likelihood: -143709
# INFO:lda:<1020> log likelihood: -143771
# INFO:lda:<1030> log likelihood: -143774
# INFO:lda:<1040> log likelihood: -143767
# INFO:lda:<1050> log likelihood: -143779
# INFO:lda:<1060> log likelihood: -143831
# INFO:lda:<1070> log likelihood: -143782
# INFO:lda:<1080> log likelihood: -143750
# INFO:lda:<1090> log likelihood: -143829
# INFO:lda:<1100> log likelihood: -143729
# INFO:lda:<1110> log likelihood: -143759
# INFO:lda:<1120> log likelihood: -143574
# INFO:lda:<1130> log likelihood: -143808
# INFO:lda:<1140> log likelihood: -143863
# INFO:lda:<1150> log likelihood: -143958
# INFO:lda:<1160> log likelihood: -143701
# INFO:lda:<1170> log likelihood: -143655
# INFO:lda:<1180> log likelihood: -143567
# INFO:lda:<1190> log likelihood: -143648
# INFO:lda:<1200> log likelihood: -143689
# INFO:lda:<1210> log likelihood: -143706
# INFO:lda:<1220> log likelihood: -143648
# INFO:lda:<1230> log likelihood: -143642
# INFO:lda:<1240> log likelihood: -143557
# INFO:lda:<1250> log likelihood: -143789
# INFO:lda:<1260> log likelihood: -143674
# INFO:lda:<1270> log likelihood: -143623
# INFO:lda:<1280> log likelihood: -143719
# INFO:lda:<1290> log likelihood: -143625
# INFO:lda:<1300> log likelihood: -143788
# INFO:lda:<1310> log likelihood: -143697
# INFO:lda:<1320> log likelihood: -143824
# INFO:lda:<1330> log likelihood: -143673
# INFO:lda:<1340> log likelihood: -143752
# INFO:lda:<1350> log likelihood: -143692
# INFO:lda:<1360> log likelihood: -143672
# INFO:lda:<1370> log likelihood: -143667
# INFO:lda:<1380> log likelihood: -143749
# INFO:lda:<1390> log likelihood: -143704
# INFO:lda:<1400> log likelihood: -143771
# INFO:lda:<1410> log likelihood: -143874
# INFO:lda:<1420> log likelihood: -143694
# INFO:lda:<1430> log likelihood: -143576
# INFO:lda:<1440> log likelihood: -143753
# INFO:lda:<1450> log likelihood: -143661
# INFO:lda:<1460> log likelihood: -143755
# INFO:lda:<1470> log likelihood: -143714
# INFO:lda:<1480> log likelihood: -143733
# INFO:lda:<1490> log likelihood: -143803
# INFO:lda:<1500> log likelihood: -143962
# INFO:lda:<1510> log likelihood: -143637
# INFO:lda:<1520> log likelihood: -143595
# INFO:lda:<1530> log likelihood: -143574
# INFO:lda:<1540> log likelihood: -143751
# INFO:lda:<1550> log likelihood: -143705
# INFO:lda:<1560> log likelihood: -143598
# INFO:lda:<1570> log likelihood: -143772
# INFO:lda:<1580> log likelihood: -143646
# INFO:lda:<1590> log likelihood: -143539
# INFO:lda:<1600> log likelihood: -143855
# INFO:lda:<1610> log likelihood: -143720
# INFO:lda:<1620> log likelihood: -143521
# INFO:lda:<1630> log likelihood: -143668
# INFO:lda:<1640> log likelihood: -143496
# INFO:lda:<1650> log likelihood: -143592
# INFO:lda:<1660> log likelihood: -143616
# INFO:lda:<1670> log likelihood: -143522
# INFO:lda:<1680> log likelihood: -143626
# INFO:lda:<1690> log likelihood: -143480
# INFO:lda:<1700> log likelihood: -143533
# INFO:lda:<1710> log likelihood: -143509
# INFO:lda:<1720> log likelihood: -143693
# INFO:lda:<1730> log likelihood: -143606
# INFO:lda:<1740> log likelihood: -143736
# INFO:lda:<1750> log likelihood: -143602
# INFO:lda:<1760> log likelihood: -143444
# INFO:lda:<1770> log likelihood: -143638
# INFO:lda:<1780> log likelihood: -143600
# INFO:lda:<1790> log likelihood: -143541
# INFO:lda:<1800> log likelihood: -143730
# INFO:lda:<1810> log likelihood: -143734
# INFO:lda:<1820> log likelihood: -143635
# INFO:lda:<1830> log likelihood: -143697
# INFO:lda:<1840> log likelihood: -143761
# INFO:lda:<1850> log likelihood: -143514
# INFO:lda:<1860> log likelihood: -143636
# INFO:lda:<1870> log likelihood: -143725
# INFO:lda:<1880> log likelihood: -143582
# INFO:lda:<1890> log likelihood: -143770
# INFO:lda:<1900> log likelihood: -143708
# INFO:lda:<1910> log likelihood: -143697
# INFO:lda:<1920> log likelihood: -143770
# INFO:lda:<1930> log likelihood: -143614
# INFO:lda:<1940> log likelihood: -143422
# INFO:lda:<1950> log likelihood: -143569
# INFO:lda:<1960> log likelihood: -143594
# INFO:lda:<1970> log likelihood: -143740
# INFO:lda:<1980> log likelihood: -143528
# INFO:lda:<1990> log likelihood: -143472
# INFO:lda:<2000> log likelihood: -143519
# INFO:lda:<2010> log likelihood: -143465
# INFO:lda:<2020> log likelihood: -143675
# INFO:lda:<2030> log likelihood: -143513
# INFO:lda:<2040> log likelihood: -143702
# INFO:lda:<2050> log likelihood: -143553
# INFO:lda:<2060> log likelihood: -143596
# INFO:lda:<2070> log likelihood: -143676
# INFO:lda:<2080> log likelihood: -143571
# INFO:lda:<2090> log likelihood: -143742
# INFO:lda:<2100> log likelihood: -143462
# INFO:lda:<2110> log likelihood: -143597
# INFO:lda:<2120> log likelihood: -143584
# INFO:lda:<2130> log likelihood: -143515
# INFO:lda:<2140> log likelihood: -143609
# INFO:lda:<2150> log likelihood: -143582
# INFO:lda:<2160> log likelihood: -143656
# INFO:lda:<2170> log likelihood: -143549
# INFO:lda:<2180> log likelihood: -143673
# INFO:lda:<2190> log likelihood: -143545
# INFO:lda:<2200> log likelihood: -143427
# INFO:lda:<2210> log likelihood: -143734
# INFO:lda:<2220> log likelihood: -143649
# INFO:lda:<2230> log likelihood: -143842
# INFO:lda:<2240> log likelihood: -143519
# INFO:lda:<2250> log likelihood: -143725
# INFO:lda:<2260> log likelihood: -143842
# INFO:lda:<2270> log likelihood: -143750
# INFO:lda:<2280> log likelihood: -143671
# INFO:lda:<2290> log likelihood: -143684
# INFO:lda:<2300> log likelihood: -143684
# INFO:lda:<2310> log likelihood: -143614
# INFO:lda:<2320> log likelihood: -143574
# INFO:lda:<2330> log likelihood: -143855
# INFO:lda:<2340> log likelihood: -143740
# INFO:lda:<2350> log likelihood: -143659
# INFO:lda:<2360> log likelihood: -143654
# INFO:lda:<2370> log likelihood: -143474
# INFO:lda:<2380> log likelihood: -143777
# INFO:lda:<2390> log likelihood: -143555
# INFO:lda:<2400> log likelihood: -143563
# INFO:lda:<2410> log likelihood: -143736
# INFO:lda:<2420> log likelihood: -143500
# INFO:lda:<2430> log likelihood: -143728
# INFO:lda:<2440> log likelihood: -143603
# INFO:lda:<2450> log likelihood: -143699
# INFO:lda:<210> log likelihood: -145352
# INFO:lda:<220> log likelihood: -145417
# INFO:lda:<230> log likelihood: -145203
# INFO:lda:<240> log likelihood: -145410
# INFO:lda:<250> log likelihood: -145319
# INFO:lda:<260> log likelihood: -145412
# INFO:lda:<270> log likelihood: -145357
# INFO:lda:<280> log likelihood: -145413
# INFO:lda:<290> log likelihood: -145390
# INFO:lda:<300> log likelihood: -145347
# INFO:lda:<310> log likelihood: -145375
# INFO:lda:<320> log likelihood: -145235
# INFO:lda:<330> log likelihood: -145226
# INFO:lda:<340> log likelihood: -145259
# INFO:lda:<350> log likelihood: -145334
# INFO:lda:<360> log likelihood: -145114
# INFO:lda:<370> log likelihood: -145135
# INFO:lda:<380> log likelihood: -145168
# INFO:lda:<390> log likelihood: -145015
# INFO:lda:<400> log likelihood: -145244
# INFO:lda:<410> log likelihood: -145084
# INFO:lda:<420> log likelihood: -145059
# INFO:lda:<430> log likelihood: -145064
# INFO:lda:<440> log likelihood: -145021
# INFO:lda:<450> log likelihood: -145088
# INFO:lda:<460> log likelihood: -144931
# INFO:lda:<470> log likelihood: -145089
# INFO:lda:<480> log likelihood: -145190
# INFO:lda:<490> log likelihood: -145099
# INFO:lda:<500> log likelihood: -144879
# INFO:lda:<510> log likelihood: -144874
# INFO:lda:<520> log likelihood: -144811
# INFO:lda:<530> log likelihood: -144895
# INFO:lda:<540> log likelihood: -145104
# INFO:lda:<550> log likelihood: -144992
# INFO:lda:<560> log likelihood: -144823
# INFO:lda:<570> log likelihood: -144948
# INFO:lda:<580> log likelihood: -144858
# INFO:lda:<590> log likelihood: -145105
# INFO:lda:<600> log likelihood: -145214
# INFO:lda:<610> log likelihood: -144868
# INFO:lda:<620> log likelihood: -144858
# INFO:lda:<630> log likelihood: -144875
# INFO:lda:<640> log likelihood: -144795
# INFO:lda:<650> log likelihood: -144763
# INFO:lda:<660> log likelihood: -144699
# INFO:lda:<670> log likelihood: -144931
# INFO:lda:<680> log likelihood: -144822
# INFO:lda:<690> log likelihood: -144674
# INFO:lda:<700> log likelihood: -144801
# INFO:lda:<710> log likelihood: -144763
# INFO:lda:<720> log likelihood: -144610
# INFO:lda:<730> log likelihood: -144561
# INFO:lda:<740> log likelihood: -144618
# INFO:lda:<750> log likelihood: -144740
# INFO:lda:<760> log likelihood: -144691
# INFO:lda:<770> log likelihood: -144980
# INFO:lda:<780> log likelihood: -144829
# INFO:lda:<790> log likelihood: -144776
# INFO:lda:<800> log likelihood: -144654
# INFO:lda:<810> log likelihood: -144919
# INFO:lda:<820> log likelihood: -144748
# INFO:lda:<830> log likelihood: -144641
# INFO:lda:<840> log likelihood: -144659
# INFO:lda:<850> log likelihood: -144620
# INFO:lda:<860> log likelihood: -144669
# INFO:lda:<870> log likelihood: -144716
# INFO:lda:<880> log likelihood: -144733
# INFO:lda:<890> log likelihood: -144730
# INFO:lda:<900> log likelihood: -144780
# INFO:lda:<910> log likelihood: -144661
# INFO:lda:<920> log likelihood: -144626
# INFO:lda:<930> log likelihood: -144779
# INFO:lda:<940> log likelihood: -144777
# INFO:lda:<950> log likelihood: -144705
# INFO:lda:<960> log likelihood: -144621
# INFO:lda:<970> log likelihood: -144709
# INFO:lda:<980> log likelihood: -144511
# INFO:lda:<990> log likelihood: -144647
# INFO:lda:<1000> log likelihood: -144579
# INFO:lda:<1010> log likelihood: -144368
# INFO:lda:<1020> log likelihood: -144446
# INFO:lda:<1030> log likelihood: -144303
# INFO:lda:<1040> log likelihood: -144203
# INFO:lda:<1050> log likelihood: -144144
# INFO:lda:<1060> log likelihood: -144414
# INFO:lda:<1070> log likelihood: -144431
# INFO:lda:<1080> log likelihood: -144386
# INFO:lda:<1090> log likelihood: -144324
# INFO:lda:<1100> log likelihood: -144277
# INFO:lda:<1110> log likelihood: -144456
# INFO:lda:<1120> log likelihood: -144364
# INFO:lda:<1130> log likelihood: -144230
# INFO:lda:<1140> log likelihood: -144512
# INFO:lda:<1150> log likelihood: -144449
# INFO:lda:<1160> log likelihood: -144464
# INFO:lda:<1170> log likelihood: -144423
# INFO:lda:<1180> log likelihood: -144448
# INFO:lda:<1190> log likelihood: -144241
# INFO:lda:<1200> log likelihood: -144629
# INFO:lda:<1210> log likelihood: -144277
# INFO:lda:<1220> log likelihood: -144504
# INFO:lda:<1230> log likelihood: -144204
# INFO:lda:<1240> log likelihood: -144473
# INFO:lda:<1250> log likelihood: -144300
# INFO:lda:<1260> log likelihood: -144288
# INFO:lda:<1270> log likelihood: -144272
# INFO:lda:<1280> log likelihood: -144428
# INFO:lda:<1290> log likelihood: -144291
# INFO:lda:<1300> log likelihood: -144119
# INFO:lda:<1310> log likelihood: -144081
# INFO:lda:<1320> log likelihood: -144409
# INFO:lda:<1330> log likelihood: -144236
# INFO:lda:<1340> log likelihood: -144428
# INFO:lda:<1350> log likelihood: -144225
# INFO:lda:<1360> log likelihood: -144163
# INFO:lda:<1370> log likelihood: -144209
# INFO:lda:<1380> log likelihood: -144103
# INFO:lda:<1390> log likelihood: -144145
# INFO:lda:<1400> log likelihood: -144170
# INFO:lda:<1410> log likelihood: -144304
# INFO:lda:<1420> log likelihood: -144211
# INFO:lda:<1430> log likelihood: -144310
# INFO:lda:<1440> log likelihood: -144253
# INFO:lda:<1450> log likelihood: -144153
# INFO:lda:<1460> log likelihood: -143960
# INFO:lda:<1470> log likelihood: -144093
# INFO:lda:<1480> log likelihood: -144217
# INFO:lda:<1490> log likelihood: -144167
# INFO:lda:<1500> log likelihood: -144150
# INFO:lda:<1510> log likelihood: -144096
# INFO:lda:<1520> log likelihood: -144185
# INFO:lda:<1530> log likelihood: -144337
# INFO:lda:<1540> log likelihood: -144259
# INFO:lda:<1550> log likelihood: -144257
# INFO:lda:<1560> log likelihood: -144110
# INFO:lda:<1570> log likelihood: -144160
# INFO:lda:<1580> log likelihood: -144196
# INFO:lda:<1590> log likelihood: -144293
# INFO:lda:<1600> log likelihood: -144294
# INFO:lda:<1610> log likelihood: -144213
# INFO:lda:<1620> log likelihood: -144081
# INFO:lda:<1630> log likelihood: -144219
# INFO:lda:<1640> log likelihood: -144328
# INFO:lda:<1650> log likelihood: -143992
# INFO:lda:<1660> log likelihood: -143913
# INFO:lda:<1670> log likelihood: -143816
# INFO:lda:<1680> log likelihood: -143987
# INFO:lda:<1690> log likelihood: -144037
# INFO:lda:<1700> log likelihood: -143902
# INFO:lda:<1710> log likelihood: -144033
# INFO:lda:<1720> log likelihood: -143872
# INFO:lda:<1730> log likelihood: -143773
# INFO:lda:<1740> log likelihood: -143842
# INFO:lda:<1750> log likelihood: -143607
# INFO:lda:<1760> log likelihood: -143812
# INFO:lda:<1770> log likelihood: -143703
# INFO:lda:<1780> log likelihood: -143869
# INFO:lda:<1790> log likelihood: -143696
# INFO:lda:<1800> log likelihood: -143844
# INFO:lda:<1810> log likelihood: -143720
# INFO:lda:<1820> log likelihood: -143689
# INFO:lda:<1830> log likelihood: -143643
# INFO:lda:<1840> log likelihood: -143906
# INFO:lda:<1850> log likelihood: -143622
# INFO:lda:<1860> log likelihood: -143847
# INFO:lda:<1870> log likelihood: -143575
# INFO:lda:<1880> log likelihood: -143655
# INFO:lda:<1890> log likelihood: -143710
# INFO:lda:<1900> log likelihood: -143724
# INFO:lda:<1910> log likelihood: -143984
# INFO:lda:<1920> log likelihood: -144018
# INFO:lda:<1930> log likelihood: -143726
# INFO:lda:<1940> log likelihood: -143611
# INFO:lda:<1950> log likelihood: -143599
# INFO:lda:<1960> log likelihood: -143833
# INFO:lda:<1970> log likelihood: -143884
# INFO:lda:<1980> log likelihood: -143692
# INFO:lda:<1990> log likelihood: -143823
# INFO:lda:<2000> log likelihood: -143998
# INFO:lda:<2010> log likelihood: -143891
# INFO:lda:<2020> log likelihood: -143681
# INFO:lda:<2030> log likelihood: -143832
# INFO:lda:<2040> log likelihood: -143731
# INFO:lda:<2050> log likelihood: -143864
# INFO:lda:<2060> log likelihood: -143689
# INFO:lda:<2070> log likelihood: -143811
# INFO:lda:<2080> log likelihood: -143689
# INFO:lda:<2090> log likelihood: -143603
# INFO:lda:<2100> log likelihood: -143752
# INFO:lda:<2110> log likelihood: -143806
# INFO:lda:<2120> log likelihood: -143868
# INFO:lda:<2130> log likelihood: -143872
# INFO:lda:<2140> log likelihood: -143814
# INFO:lda:<2150> log likelihood: -143815
# INFO:lda:<2160> log likelihood: -143706
# INFO:lda:<2170> log likelihood: -143659
# INFO:lda:<2180> log likelihood: -143936
# INFO:lda:<2190> log likelihood: -143713
# INFO:lda:<2200> log likelihood: -143812
# INFO:lda:<2210> log likelihood: -144011
# INFO:lda:<2220> log likelihood: -143953
# INFO:lda:<2230> log likelihood: -143748
# INFO:lda:<2240> log likelihood: -143759
# INFO:lda:<2250> log likelihood: -143882
# INFO:lda:<2260> log likelihood: -143764
# INFO:lda:<2270> log likelihood: -143875
# INFO:lda:<2280> log likelihood: -143846
# INFO:lda:<2290> log likelihood: -143981
# INFO:lda:<2300> log likelihood: -143839
# INFO:lda:<2310> log likelihood: -143818
# INFO:lda:<2320> log likelihood: -143780
# INFO:lda:<3030> log likelihood: -143121
# INFO:lda:<3040> log likelihood: -143270
# INFO:lda:<3050> log likelihood: -143077
# INFO:lda:<3060> log likelihood: -143234
# INFO:lda:<3070> log likelihood: -143151
# INFO:lda:<3080> log likelihood: -143199
# INFO:lda:<3090> log likelihood: -143121
# INFO:lda:<3100> log likelihood: -143357
# INFO:lda:<3110> log likelihood: -143166
# INFO:lda:<3120> log likelihood: -143293
# INFO:lda:<3130> log likelihood: -143280
# INFO:lda:<3140> log likelihood: -143205
# INFO:lda:<3150> log likelihood: -143146
# INFO:lda:<3160> log likelihood: -143048
# INFO:lda:<3170> log likelihood: -143434
# INFO:lda:<3180> log likelihood: -143260
# INFO:lda:<3190> log likelihood: -143203
# INFO:lda:<3200> log likelihood: -143303
# INFO:lda:<3210> log likelihood: -143160
# INFO:lda:<3220> log likelihood: -143201
# INFO:lda:<3230> log likelihood: -143127
# INFO:lda:<3240> log likelihood: -143021
# INFO:lda:<3250> log likelihood: -143235
# INFO:lda:<3260> log likelihood: -143077
# INFO:lda:<3270> log likelihood: -143129
# INFO:lda:<3280> log likelihood: -143167
# INFO:lda:<3290> log likelihood: -143188
# INFO:lda:<3300> log likelihood: -143194
# INFO:lda:<3310> log likelihood: -143175
# INFO:lda:<3320> log likelihood: -142962
# INFO:lda:<3330> log likelihood: -143132
# INFO:lda:<3340> log likelihood: -143141
# INFO:lda:<3350> log likelihood: -143083
# INFO:lda:<3360> log likelihood: -143154
# INFO:lda:<3370> log likelihood: -143069
# INFO:lda:<3380> log likelihood: -143232
# INFO:lda:<3390> log likelihood: -143164
# INFO:lda:<3400> log likelihood: -143161
# INFO:lda:<3410> log likelihood: -143279
# INFO:lda:<3420> log likelihood: -143199
# INFO:lda:<3430> log likelihood: -143104
# INFO:lda:<3440> log likelihood: -143109
# INFO:lda:<3450> log likelihood: -142990
# INFO:lda:<3460> log likelihood: -143092
# INFO:lda:<3470> log likelihood: -143048
# INFO:lda:<3480> log likelihood: -143181
# INFO:lda:<3490> log likelihood: -143137
# INFO:lda:<3500> log likelihood: -143188
# INFO:lda:<3510> log likelihood: -143141
# INFO:lda:<3520> log likelihood: -143093
# INFO:lda:<3530> log likelihood: -143216
# INFO:lda:<3540> log likelihood: -143140
# INFO:lda:<3550> log likelihood: -143164
# INFO:lda:<3560> log likelihood: -143108
# INFO:lda:<3570> log likelihood: -143233
# INFO:lda:<3580> log likelihood: -143124
# INFO:lda:<3590> log likelihood: -143271
# INFO:lda:<3600> log likelihood: -143287
# INFO:lda:<3610> log likelihood: -143345
# INFO:lda:<3620> log likelihood: -143310
# INFO:lda:<3630> log likelihood: -143263
# INFO:lda:<3640> log likelihood: -143357
# INFO:lda:<3650> log likelihood: -143154
# INFO:lda:<3660> log likelihood: -143400
# INFO:lda:<3670> log likelihood: -143152
# INFO:lda:<3680> log likelihood: -143197
# INFO:lda:<3690> log likelihood: -143150
# INFO:lda:<3700> log likelihood: -143088
# INFO:lda:<3710> log likelihood: -143314
# INFO:lda:<70> log likelihood: -146808
# INFO:lda:<80> log likelihood: -146504
# INFO:lda:<90> log likelihood: -146332
# INFO:lda:<100> log likelihood: -146321
# INFO:lda:<110> log likelihood: -146216
# INFO:lda:<120> log likelihood: -146232
# INFO:lda:<130> log likelihood: -146003
# INFO:lda:<140> log likelihood: -146015
# INFO:lda:<150> log likelihood: -146136
# INFO:lda:<160> log likelihood: -146017
# INFO:lda:<170> log likelihood: -145699
# INFO:lda:<180> log likelihood: -145605
# INFO:lda:<190> log likelihood: -145613
# INFO:lda:<200> log likelihood: -145360
# INFO:lda:<210> log likelihood: -145326
# INFO:lda:<220> log likelihood: -145212
# INFO:lda:<230> log likelihood: -145308
# INFO:lda:<240> log likelihood: -145350
# INFO:lda:<250> log likelihood: -145345
# INFO:lda:<260> log likelihood: -145465
# INFO:lda:<270> log likelihood: -145303
# INFO:lda:<280> log likelihood: -145218
# INFO:lda:<290> log likelihood: -145164
# INFO:lda:<300> log likelihood: -145001
# INFO:lda:<310> log likelihood: -145031
# INFO:lda:<320> log likelihood: -145176
# INFO:lda:<330> log likelihood: -144827
# INFO:lda:<340> log likelihood: -144927
# INFO:lda:<350> log likelihood: -144778
# INFO:lda:<360> log likelihood: -144831
# INFO:lda:<370> log likelihood: -144789
# INFO:lda:<380> log likelihood: -144780
# INFO:lda:<390> log likelihood: -144779
# INFO:lda:<400> log likelihood: -144881
# INFO:lda:<410> log likelihood: -144712
# INFO:lda:<420> log likelihood: -144750
# INFO:lda:<430> log likelihood: -145041
# INFO:lda:<440> log likelihood: -144743
# INFO:lda:<450> log likelihood: -144763
# INFO:lda:<460> log likelihood: -144531
# INFO:lda:<470> log likelihood: -144771
# INFO:lda:<480> log likelihood: -144614
# INFO:lda:<490> log likelihood: -144591
# INFO:lda:<500> log likelihood: -144552
# INFO:lda:<510> log likelihood: -144673
# INFO:lda:<520> log likelihood: -144736
# INFO:lda:<530> log likelihood: -144758
# INFO:lda:<540> log likelihood: -144591
# INFO:lda:<550> log likelihood: -144716
# INFO:lda:<560> log likelihood: -144504
# INFO:lda:<570> log likelihood: -144543
# INFO:lda:<580> log likelihood: -144677
# INFO:lda:<590> log likelihood: -144397
# INFO:lda:<600> log likelihood: -144490
# INFO:lda:<610> log likelihood: -144499
# INFO:lda:<620> log likelihood: -144445
# INFO:lda:<630> log likelihood: -144513
# INFO:lda:<640> log likelihood: -144343
# INFO:lda:<650> log likelihood: -144529
# INFO:lda:<660> log likelihood: -144610
# INFO:lda:<670> log likelihood: -144503
# INFO:lda:<680> log likelihood: -144112
# INFO:lda:<690> log likelihood: -144022
# INFO:lda:<700> log likelihood: -144028
# INFO:lda:<710> log likelihood: -144196
# INFO:lda:<720> log likelihood: -143947
# INFO:lda:<730> log likelihood: -144180
# INFO:lda:<740> log likelihood: -144232
# INFO:lda:<750> log likelihood: -144034
# INFO:lda:<760> log likelihood: -144283
# INFO:lda:<770> log likelihood: -143925
# INFO:lda:<780> log likelihood: -143793
# INFO:lda:<790> log likelihood: -143916
# INFO:lda:<800> log likelihood: -144101
# INFO:lda:<810> log likelihood: -143920
# INFO:lda:<820> log likelihood: -143868
# INFO:lda:<830> log likelihood: -143751
# INFO:lda:<840> log likelihood: -143697
# INFO:lda:<850> log likelihood: -143725
# INFO:lda:<860> log likelihood: -143888
# INFO:lda:<870> log likelihood: -143757
# INFO:lda:<880> log likelihood: -143817
# INFO:lda:<890> log likelihood: -143787
# INFO:lda:<900> log likelihood: -143925
# INFO:lda:<910> log likelihood: -143875
# INFO:lda:<920> log likelihood: -143686
# INFO:lda:<930> log likelihood: -143752
# INFO:lda:<940> log likelihood: -143906
# INFO:lda:<950> log likelihood: -143905
# INFO:lda:<960> log likelihood: -143843
# INFO:lda:<970> log likelihood: -143725
# INFO:lda:<980> log likelihood: -143826
# INFO:lda:<990> log likelihood: -143682
# INFO:lda:<1000> log likelihood: -143649
# INFO:lda:<1010> log likelihood: -143654
# INFO:lda:<1020> log likelihood: -143738
# INFO:lda:<1030> log likelihood: -143586
# INFO:lda:<1040> log likelihood: -143663
# INFO:lda:<1050> log likelihood: -143755
# INFO:lda:<1060> log likelihood: -143741
# INFO:lda:<1070> log likelihood: -143644
# INFO:lda:<1080> log likelihood: -143507
# INFO:lda:<1090> log likelihood: -143773
# INFO:lda:<1100> log likelihood: -143753
# INFO:lda:<1110> log likelihood: -143567
# INFO:lda:<1120> log likelihood: -143673
# INFO:lda:<1130> log likelihood: -143703
# INFO:lda:<1140> log likelihood: -143585
# INFO:lda:<1150> log likelihood: -143491
# INFO:lda:<1160> log likelihood: -143557
# INFO:lda:<1170> log likelihood: -143740
# INFO:lda:<1180> log likelihood: -143759
# INFO:lda:<1190> log likelihood: -143809
# INFO:lda:<1200> log likelihood: -143597
# INFO:lda:<1210> log likelihood: -143794
# INFO:lda:<1220> log likelihood: -143732
# INFO:lda:<1230> log likelihood: -143730
# INFO:lda:<1240> log likelihood: -143675
# INFO:lda:<1250> log likelihood: -143614
# INFO:lda:<1260> log likelihood: -143562
# INFO:lda:<1270> log likelihood: -143522
# INFO:lda:<1280> log likelihood: -143636
# INFO:lda:<1290> log likelihood: -143636
# INFO:lda:<1300> log likelihood: -143548
# INFO:lda:<1310> log likelihood: -143469
# INFO:lda:<1320> log likelihood: -143726
# INFO:lda:<1330> log likelihood: -143801
# INFO:lda:<1340> log likelihood: -143528
# INFO:lda:<1350> log likelihood: -143546
# INFO:lda:<1360> log likelihood: -143585
# INFO:lda:<1370> log likelihood: -143587
# INFO:lda:<1380> log likelihood: -143808
# INFO:lda:<1390> log likelihood: -143627
# INFO:lda:<1400> log likelihood: -143671
# INFO:lda:<1410> log likelihood: -143638
# INFO:lda:<1420> log likelihood: -143680
# INFO:lda:<1430> log likelihood: -143725
# INFO:lda:<1440> log likelihood: -143540
# INFO:lda:<1450> log likelihood: -143479
# INFO:lda:<1460> log likelihood: -143420
# INFO:lda:<1470> log likelihood: -143574
# INFO:lda:<1480> log likelihood: -143488
# INFO:lda:<1490> log likelihood: -143587
# INFO:lda:<1500> log likelihood: -143612
# INFO:lda:<1510> log likelihood: -143632
# INFO:lda:<1520> log likelihood: -143609
# INFO:lda:<1530> log likelihood: -143611
# INFO:lda:<1540> log likelihood: -143778
# INFO:lda:<1550> log likelihood: -143479
# INFO:lda:<1560> log likelihood: -143670
# INFO:lda:<1570> log likelihood: -143637
# INFO:lda:<1580> log likelihood: -143601
# INFO:lda:<1590> log likelihood: -143639
# INFO:lda:<1600> log likelihood: -143461
# INFO:lda:<1610> log likelihood: -143642
# INFO:lda:<1620> log likelihood: -143413
# INFO:lda:<1630> log likelihood: -143469
# INFO:lda:<1640> log likelihood: -143493
# INFO:lda:<1650> log likelihood: -143595
# INFO:lda:<1660> log likelihood: -143605
# INFO:lda:<1670> log likelihood: -143662
# INFO:lda:<1680> log likelihood: -143598
# INFO:lda:<1690> log likelihood: -143529
# INFO:lda:<1700> log likelihood: -143556
# INFO:lda:<1710> log likelihood: -143599
# INFO:lda:<1720> log likelihood: -143717
# INFO:lda:<1730> log likelihood: -143523
# INFO:lda:<1740> log likelihood: -143509
# INFO:lda:<1750> log likelihood: -143627
# INFO:lda:<1760> log likelihood: -143661
# INFO:lda:<1770> log likelihood: -143448
# INFO:lda:<1780> log likelihood: -143632
# INFO:lda:<1790> log likelihood: -143384
# INFO:lda:<1800> log likelihood: -143586
# INFO:lda:<1810> log likelihood: -143409
# INFO:lda:<1820> log likelihood: -143604
# INFO:lda:<1830> log likelihood: -143705
# INFO:lda:<1840> log likelihood: -143539
# INFO:lda:<1850> log likelihood: -143579
# INFO:lda:<1860> log likelihood: -143509
# INFO:lda:<1870> log likelihood: -143640
# INFO:lda:<1880> log likelihood: -143587
# INFO:lda:<1890> log likelihood: -143445
# INFO:lda:<1900> log likelihood: -143690
# INFO:lda:<1910> log likelihood: -143526
# INFO:lda:<1920> log likelihood: -143543
# INFO:lda:<1930> log likelihood: -143613
# INFO:lda:<1940> log likelihood: -143516
# INFO:lda:<1950> log likelihood: -143496
# INFO:lda:<1960> log likelihood: -143564
# ...
# INFO:lda:<1310> log likelihood: -143241
# INFO:lda:<1320> log likelihood: -143036
# INFO:lda:<1330> log likelihood: -143289
# INFO:lda:<1340> log likelihood: -143208
# INFO:lda:<1350> log likelihood: -143227
# INFO:lda:<1360> log likelihood: -143116
# INFO:lda:<1370> log likelihood: -143208
# INFO:lda:<1380> log likelihood: -143289
# INFO:lda:<1390> log likelihood: -143276
# INFO:lda:<1400> log likelihood: -143208
# INFO:lda:<1410> log likelihood: -143190
# INFO:lda:<1420> log likelihood: -143211
# INFO:lda:<1430> log likelihood: -143094
# INFO:lda:<1440> log likelihood: -143298
# INFO:lda:<1450> log likelihood: -143275
# INFO:lda:<1460> log likelihood: -143173
# INFO:lda:<1470> log likelihood: -143285
# INFO:lda:<1480> log likelihood: -143317
# INFO:lda:<1490> log likelihood: -143205
# INFO:lda:<1500> log likelihood: -143044
# INFO:lda:<1510> log likelihood: -143220
# INFO:lda:<1520> log likelihood: -143202
# INFO:lda:<1530> log likelihood: -142956
# INFO:lda:<1540> log likelihood: -143219
# INFO:lda:<1550> log likelihood: -142966
# INFO:lda:<1560> log likelihood: -143064
# INFO:lda:<1570> log likelihood: -143272
# INFO:lda:<1580> log likelihood: -143140
# INFO:lda:<1590> log likelihood: -143272
# INFO:lda:<1600> log likelihood: -143285
# INFO:lda:<1610> log likelihood: -143162
# INFO:lda:<1620> log likelihood: -143132
# INFO:lda:<1630> log likelihood: -143262
# INFO:lda:<1640> log likelihood: -143120
# INFO:lda:<1650> log likelihood: -143017
# INFO:lda:<1660> log likelihood: -143119
# INFO:lda:<1670> log likelihood: -143342
# INFO:lda:<1680> log likelihood: -143177
# INFO:lda:<1690> log likelihood: -142925
# INFO:lda:<1700> log likelihood: -143141
# INFO:lda:<1710> log likelihood: -143060
# INFO:lda:<1720> log likelihood: -143240
# INFO:lda:<1730> log likelihood: -143231
# INFO:lda:<1740> log likelihood: -143042
# INFO:lda:<1750> log likelihood: -143191
# INFO:lda:<1760> log likelihood: -143226
# INFO:lda:<1770> log likelihood: -143278
# INFO:lda:<1780> log likelihood: -143300
# INFO:lda:<1790> log likelihood: -143356
# INFO:lda:<1800> log likelihood: -143249
# INFO:lda:<1810> log likelihood: -143123
# INFO:lda:<1820> log likelihood: -143103
# INFO:lda:<1830> log likelihood: -143043
# INFO:lda:<1840> log likelihood: -143084
# INFO:lda:<1850> log likelihood: -143143
# INFO:lda:<1860> log likelihood: -143006
# INFO:lda:<1870> log likelihood: -143030
# INFO:lda:<1880> log likelihood: -143244
# INFO:lda:<1890> log likelihood: -143156
# INFO:lda:<1900> log likelihood: -143188
# INFO:lda:<1910> log likelihood: -143052
# INFO:lda:<1920> log likelihood: -142995
# INFO:lda:<1930> log likelihood: -143164
# INFO:lda:<1940> log likelihood: -143193
# INFO:lda:<1950> log likelihood: -143137
# INFO:lda:<1960> log likelihood: -143264
# INFO:lda:<1970> log likelihood: -143289
# INFO:lda:<1980> log likelihood: -142872
# INFO:lda:<1990> log likelihood: -143222
# INFO:lda:<2000> log likelihood: -143031
# INFO:lda:<2010> log likelihood: -142950
# INFO:lda:<2020> log likelihood: -143018
# INFO:lda:<2030> log likelihood: -143153
# INFO:lda:<2040> log likelihood: -143071
# INFO:lda:<2050> log likelihood: -143182
# INFO:lda:<2060> log likelihood: -143196
# INFO:lda:<2070> log likelihood: -143090
# INFO:lda:<2080> log likelihood: -143187
# INFO:lda:<2090> log likelihood: -143058
# INFO:lda:<2100> log likelihood: -143115
# INFO:lda:<2110> log likelihood: -143131
# INFO:lda:<2120> log likelihood: -143104
# INFO:lda:<2130> log likelihood: -143039
# INFO:lda:<2140> log likelihood: -143343
# INFO:lda:<2150> log likelihood: -143169
# INFO:lda:<2160> log likelihood: -142956
# INFO:lda:<2170> log likelihood: -143101
# INFO:lda:<2180> log likelihood: -143091
# INFO:lda:<2190> log likelihood: -142958
# INFO:lda:<2200> log likelihood: -143110
# INFO:lda:<2210> log likelihood: -143016
# INFO:lda:<2220> log likelihood: -143138
# INFO:lda:<2230> log likelihood: -143130
# INFO:lda:<2240> log likelihood: -143429
# INFO:lda:<2250> log likelihood: -143154
# INFO:lda:<2260> log likelihood: -143132
# INFO:lda:<2270> log likelihood: -143193
# INFO:lda:<2280> log likelihood: -143176
# INFO:lda:<2290> log likelihood: -143087
# INFO:lda:<2300> log likelihood: -143231
# INFO:lda:<2310> log likelihood: -143104
# INFO:lda:<2320> log likelihood: -142942
# INFO:lda:<2330> log likelihood: -143183
# INFO:lda:<2340> log likelihood: -143166
# INFO:lda:<2350> log likelihood: -143261
# INFO:lda:<2360> log likelihood: -143183
# INFO:lda:<2370> log likelihood: -143194
# INFO:lda:<2380> log likelihood: -143089
# INFO:lda:<2390> log likelihood: -143094
# INFO:lda:<2400> log likelihood: -143366
# INFO:lda:<2410> log likelihood: -143089
# INFO:lda:<2420> log likelihood: -143147
# INFO:lda:<2430> log likelihood: -143040
# INFO:lda:<2440> log likelihood: -143121
# INFO:lda:<2450> log likelihood: -143188
# INFO:lda:<2460> log likelihood: -143078
# INFO:lda:<2470> log likelihood: -143476
# INFO:lda:<2480> log likelihood: -143235
# INFO:lda:<2490> log likelihood: -143224
# INFO:lda:<2500> log likelihood: -143078
# INFO:lda:<2510> log likelihood: -143133
# INFO:lda:<2520> log likelihood: -143175
# INFO:lda:<2530> log likelihood: -143018
# INFO:lda:<2540> log likelihood: -143138
# INFO:lda:<2550> log likelihood: -143188
# INFO:lda:<2560> log likelihood: -143280
# INFO:lda:<2570> log likelihood: -143145
# INFO:lda:<2580> log likelihood: -143063
# INFO:lda:<2590> log likelihood: -143037
# INFO:lda:<2600> log likelihood: -143043
# INFO:lda:<2610> log likelihood: -143300
# INFO:lda:<2620> log likelihood: -143079
# INFO:lda:<2630> log likelihood: -143304
# INFO:lda:<2640> log likelihood: -143251
# INFO:lda:<2650> log likelihood: -143042
# INFO:lda:<2660> log likelihood: -143049
# INFO:lda:<2670> log likelihood: -143378
# INFO:lda:<2680> log likelihood: -143095
# INFO:lda:<2690> log likelihood: -143180
# INFO:lda:<2700> log likelihood: -143322
# INFO:lda:<2710> log likelihood: -143126
# INFO:lda:<2720> log likelihood: -143372
# INFO:lda:<2730> log likelihood: -143238
# INFO:lda:<2740> log likelihood: -143343
# INFO:lda:<2750> log likelihood: -143224
# INFO:lda:<2760> log likelihood: -143148
# INFO:lda:<2770> log likelihood: -143177
# INFO:lda:<2780> log likelihood: -143036
# INFO:lda:<2790> log likelihood: -143095
# INFO:lda:<2800> log likelihood: -143210
# INFO:lda:<2810> log likelihood: -143299
# INFO:lda:<2820> log likelihood: -143089
# INFO:lda:<2830> log likelihood: -143131
# INFO:lda:<2840> log likelihood: -143199
# INFO:lda:<2850> log likelihood: -143104
# INFO:lda:<2860> log likelihood: -143147
# INFO:lda:<2870> log likelihood: -143121
# INFO:lda:<2880> log likelihood: -143137
# INFO:lda:<2890> log likelihood: -143277
# INFO:lda:<2900> log likelihood: -143198
# INFO:lda:<2910> log likelihood: -143249
# INFO:lda:<2920> log likelihood: -143125
# INFO:lda:<2930> log likelihood: -143147
# INFO:lda:<2940> log likelihood: -143200
# INFO:lda:<2950> log likelihood: -143311
# INFO:lda:<2960> log likelihood: -143282
# INFO:lda:<2970> log likelihood: -143302
# INFO:lda:<2980> log likelihood: -143355
# INFO:lda:<2990> log likelihood: -143202
# INFO:lda:<3000> log likelihood: -143266
# INFO:lda:<3010> log likelihood: -143307
# INFO:lda:<3020> log likelihood: -143239
# INFO:lda:<3030> log likelihood: -143232
# INFO:lda:<3040> log likelihood: -143234
# INFO:lda:<3050> log likelihood: -143229
# INFO:lda:<3060> log likelihood: -143302
# INFO:lda:<3070> log likelihood: -143018
# INFO:lda:<3080> log likelihood: -142948
# INFO:lda:<3090> log likelihood: -143204
# INFO:lda:<3100> log likelihood: -143246
# INFO:lda:<3110> log likelihood: -143207
# INFO:lda:<3120> log likelihood: -143231
# INFO:lda:<3130> log likelihood: -143217
# INFO:lda:<3140> log likelihood: -143354
# INFO:lda:<3150> log likelihood: -143245
# INFO:lda:<3160> log likelihood: -143181
# INFO:lda:<3170> log likelihood: -143191
# INFO:lda:<3180> log likelihood: -143109
# INFO:lda:<3190> log likelihood: -143104
# INFO:lda:<3200> log likelihood: -143212
# INFO:lda:<3210> log likelihood: -143176
# INFO:lda:<3220> log likelihood: -142991
# INFO:lda:<3230> log likelihood: -143127
# INFO:lda:<3240> log likelihood: -143174
# INFO:lda:<3250> log likelihood: -142959
# INFO:lda:<3260> log likelihood: -143252
# INFO:lda:<3270> log likelihood: -142932
# INFO:lda:<3280> log likelihood: -143164
# INFO:lda:<3290> log likelihood: -143177
# INFO:lda:<3300> log likelihood: -143333
# INFO:lda:<3310> log likelihood: -143334
# INFO:lda:<3320> log likelihood: -143142
# INFO:lda:<3330> log likelihood: -143143
# INFO:lda:<3340> log likelihood: -143287
# INFO:lda:<3350> log likelihood: -143157
# INFO:lda:<3360> log likelihood: -143190
# INFO:lda:<3370> log likelihood: -142992
# INFO:lda:<3380> log likelihood: -143233
# INFO:lda:<3390> log likelihood: -143274
# INFO:lda:<3400> log likelihood: -143062
# INFO:lda:<3410> log likelihood: -142992
# INFO:lda:<3420> log likelihood: -143292
# INFO:lda:<3430> log likelihood: -143149
# INFO:lda:<3440> log likelihood: -143139
# INFO:lda:<3450> log likelihood: -143223
# INFO:lda:<3460> log likelihood: -143177
# INFO:lda:<3470> log likelihood: -143084
# INFO:lda:<3480> log likelihood: -143063
# INFO:lda:<3490> log likelihood: -143108
# INFO:lda:<3500> log likelihood: -143157
# INFO:lda:<3510> log likelihood: -143064
# INFO:lda:<3520> log likelihood: -143181
# INFO:lda:<3530> log likelihood: -143230
# INFO:lda:<3540> log likelihood: -143172
# INFO:lda:<3550> log likelihood: -143034
# INFO:lda:<3560> log likelihood: -142985
# INFO:lda:<3570> log likelihood: -143149
# INFO:lda:<3580> log likelihood: -143150
# INFO:lda:<3590> log likelihood: -143145
# INFO:lda:<3600> log likelihood: -143118
# INFO:lda:<3610> log likelihood: -143090
# INFO:lda:vocab_size: 412
# INFO:lda:n_words: 31088
# INFO:lda:n_topics: 7
# INFO:lda:n_iter: 5000
# INFO:lda:<0> log likelihood: -243146
# INFO:lda:<10> log likelihood: -154892
# INFO:lda:<20> log likelihood: -150983
# INFO:lda:<30> log likelihood: -148715
# INFO:lda:<40> log likelihood: -147905
# INFO:lda:<50> log likelihood: -147293
# INFO:lda:<60> log likelihood: -146828
# INFO:lda:<70> log likelihood: -146449
# INFO:lda:<80> log likelihood: -146074
# INFO:lda:<90> log likelihood: -145998
# INFO:lda:<100> log likelihood: -145877
# INFO:lda:<110> log likelihood: -145854
# INFO:lda:<120> log likelihood: -145584
# INFO:lda:<130> log likelihood: -145755
# INFO:lda:<140> log likelihood: -145787
# INFO:lda:<150> log likelihood: -145852
# INFO:lda:<160> log likelihood: -145777
# INFO:lda:<170> log likelihood: -145615
# INFO:lda:<180> log likelihood: -145563
# INFO:lda:<190> log likelihood: -145360
# INFO:lda:<200> log likelihood: -145393
# INFO:lda:<210> log likelihood: -145526
# INFO:lda:<220> log likelihood: -145287
# INFO:lda:<230> log likelihood: -145203
# INFO:lda:<240> log likelihood: -145073
# INFO:lda:<250> log likelihood: -145032
# INFO:lda:<260> log likelihood: -144900
# INFO:lda:<270> log likelihood: -145068

# %%
# perform_lda_and_save(8, 'lda_topics_8.txt')

# %%
# perform_lda_and_save(9, 'lda_topics_9.txt')

# %%
# # 토픽 수와 랜덤 시드 설정
# n_topics_list = [7, 8, 9]
# n_models = 50
# n_iter = 5000
# random_seeds = np.random.randint(0, 10000, n_models)

# # 결과 저장을 위한 파일명 설정
# output_files = {7: 'lda_topics_7.txt', 8: 'lda_topics_8.txt', 9: 'lda_topics_9.txt'}

# # 각 토픽 수에 대해 50개의 모델을 생성하고 결과를 저장합니다.
# for n_topics in n_topics_list:
#     with open(output_files[n_topics], 'w') as f:
#         for seed in random_seeds:
#             model = lda.LDA(n_topics=n_topics, n_iter=n_iter, random_state=seed)
#             model.fit(count_matrix)
            
#             f.write(f'Random Seed: {seed}\n')
#             for i, topic_dist in enumerate(model.topic_word_):
#                 topic_words = np.array(count_vectorizer.get_feature_names_out())[np.argsort(topic_dist)][:-11:-1]
#                 f.write(f'Topic {i}: {" ".join(topic_words)}\n')
#             f.write('\n')

# %%
# 퍼플렉시티 계산 함수
def calculate_perplexity(model, dtm):
    gamma = model.transform(dtm)
    beta = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
    
    prob = np.dot(gamma, beta)
    prob[prob == 0] = np.finfo(np.float32).eps
    log_likelihood = np.sum(np.log(prob) * dtm.toarray())
    perplexity = np.exp(-log_likelihood / np.sum(dtm.toarray()))
    return perplexity

# 토픽 수에 따른 퍼플렉시티 계산
def evaluate_perplexity(dtm, min_topics=2, max_topics=10):
    results = []
    for num_topics in range(min_topics, max_topics + 1):
        model = lda.LDA(n_topics=num_topics, n_iter=5000, random_state=4)
        model.fit(dtm)
        perplexity = calculate_perplexity(model, dtm)
        results.append((num_topics, perplexity))
    return pd.DataFrame(results, columns=["num_topics", "perplexity"])

# 퍼플렉시티 평가 및 결과 출력
results = evaluate_perplexity(count_matrix, min_topics=2, max_topics=10)
print(results)

# %%
# 결과 시각화
chart = alt.Chart(results).mark_line(point=True).encode(
    x=alt.X('num_topics', title='Number of Topics'),
    y=alt.Y('perplexity', title='Perplexity'),
    tooltip=['num_topics', 'perplexity']
).properties(
    title='Perplexity by Number of Topics'
)

chart.show()
# Out:
# alt.Chart(...)

# %%
# 문서별 토픽 할당 추출
topic_assignments = model.doc_topic_.argmax(axis=1)

# LDA 토픽 분포 추출
topic_distributions = model.doc_topic_

# 데이터 프레임 생성
assignments_df = pd.DataFrame({'doc_id': np.arange(len(topic_assignments)), 'topic': topic_assignments})
distributions_df = pd.DataFrame(topic_distributions, columns=[f'topic_{i}' for i in range(n_topics)])
distributions_df['doc_id'] = np.arange(len(topic_distributions))
# print(topic_assignments)
# print(distributions_df['doc_id'])

# %%
# GTM 모델 학습 및 변환
gtm_model = eGTM(k=9, model="responsibilities").fit(topic_distributions)
gtm_means = eGTM(k=9, model="means").fit_transform(topic_distributions)
gtm_modes = eGTM(k=9, model="modes").fit_transform(topic_distributions)

# %%
# GTM 결과 시각화
dgtm_modes = pd.DataFrame(gtm_modes, columns=["x1", "x2"])
dgtm_modes["topic"] = topic_assignments

gtm_modes_chart = alt.Chart(dgtm_modes).mark_circle().encode(
    x='x1',
    y='x2',
    color=alt.Color('topic:N', scale=alt.Scale(scheme='viridis')),
    size=alt.value(100),
    tooltip=['x1', 'x2', 'topic:N']
).properties(title="GTM (modes)", width=400, height=400)

dgtm_means = pd.DataFrame(gtm_means, columns=["x1", "x2"])
dgtm_means["topic"] = topic_assignments

gtm_means_chart = alt.Chart(dgtm_means).mark_circle().encode(
    x='x1',
    y='x2',
    color=alt.Color('topic:N', scale=alt.Scale(scheme='viridis')),
    size=alt.value(100),
    tooltip=['x1', 'x2', 'topic:N']
).properties(title="GTM (means)", width=400, height=400)

# %%
# 두 시각화 결합
gtm_chart = gtm_means_chart | gtm_modes_chart
gtm_chart.display()
# Out:
# alt.HConcatChart(...)

# %%
# Construct GTM
gtm_all = eGTM(k=9, model="responsibilities").fit(topic_distributions)

gtm_modes_all = eGTM(k=9, model="modes").fit_transform(topic_distributions)

dgtm_modes_all = pd.DataFrame(gtm_modes_all, columns=["x1", "x2"])
# dgtm_modes["label"] = y

gtm_modes_all = alt.Chart(dgtm_modes_all).mark_circle().encode(
    x='x1',
    y='x2',
#    color=alt.Color('label:N',
#                    scale=alt.Scale(scheme='viridis')),
    size=alt.value(3000),
    tooltip=['x1','x2','label:N']
).properties(title = "GTM (modes)", width = 500, height = 500)

# %%
transformed = gtm_all.transform(topic_distributions)
gtm_all = gtm_all.optimizedModel.matY

gtm_all = pd.DataFrame(gtm_all)
# Transpose the dataframe
gtm_all_transposed = gtm_all.transpose()

# Save the transposed dataframe to CSV
gtm_all_transposed.to_csv("/Users/woosu/Desktop/KLIP/gtm_transposed_k7_19.csv")
